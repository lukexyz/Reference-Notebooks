# %% [markdown]
# # K-Nearest Neighbors Classifier (scikit-learn-knn)
#
# >By Luke Woods (Reference:
# > [PyCon 2015 Scikit-learn Tutorial](https://github.com/jakevdp/sklearn_pycon2015))
#
# Exploring K Means Clustering
#
# * K Means is an algorithm for unsupervised clustering that is, finding clusters in data based on the data attributes alone (not the labels).
# * K Means is an unsupervised clustering technique.
#
# K Means is a relatively easy-to-understand algorithm. It searches for cluster centers which are the mean of the points within them, such that every point is closest to the cluster center it is assigned to.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

import seaborn as sns; sns.set()

# %% [markdown]
# ## 1. Sample Data

# %%
from sklearn.datasets.samples_generator import make_blobs
X, y = make_blobs(n_samples=300, centers=4,
                 random_state=0, cluster_std=0.60)

plt.scatter(X[:, 0], X[:, 1], s=40);

# %% [markdown]
# ## 2. Fit K-Means Cluster

# %%
from sklearn.cluster import KMeans

model = KMeans(4)  # 4 clusters
model.fit(X)
y_kmeans = model.predict(X)
plt.scatter(X[:, 0], X[:, 1], c=y_kmeans, s=50, cmap='rainbow');

# %%
model.predict(X)
# Out:
# array([0, 1, 3, 1, 0, 0, 2, 3, 1, 1, 2, 1, 3, 1, 0, 3, 3, 0, 2, 2, 0, 0, 3,
#        2, 2, 3, 0, 3, 2, 3, 1, 1, 3, 1, 1, 1, 1, 1, 2, 0, 3, 2, 3, 3, 2, 2,
#        1, 2, 1, 0, 2, 0, 1, 0, 0, 2, 1, 2, 1, 0, 1, 3, 1, 2, 2, 2, 1, 0, 1,
#        2, 3, 2, 1, 2, 2, 1, 2, 3, 0, 1, 0, 3, 0, 0, 1, 3, 0, 3, 1, 1, 3, 0,
#        1, 2, 2, 3, 0, 0, 3, 2, 1, 0, 1, 0, 3, 0, 0, 3, 1, 3, 2, 2, 0, 1, 0,
#        3, 1, 0, 0, 3, 2, 0, 2, 0, 0, 0, 0, 2, 0, 2, 1, 2, 2, 0, 1, 2, 2, 1,
#        3, 1, 1, 2, 3, 2, 3, 2, 1, 3, 1, 1, 1, 3, 1, 3, 0, 2, 1, 2, 0, 3, 1,
#        3, 3, 0, 3, 2, 2, 3, 0, 3, 3, 1, 0, 3, 2, 1, 0, 0, 3, 2, 0, 3, 2, 2,
#        3, 3, 3, 3, 0, 1, 3, 2, 3, 3, 2, 2, 2, 3, 2, 1, 3, 2, 0, 2, 3, 1, 2,
#        1, 3, 1, 3, 2, 3, 3, 1, 2, 2, 0, 0, 3, 1, 0, 0, 2, 0, 2, 3, 1, 1, 3,
#        3, 1, 3, 0, 2, 3, 0, 2, 1, 2, 0, 3, 0, 1, 1, 1, 1, 2, 2, 1, 3, 2, 0,
#        3, 2, 2, 2, 0, 0, 1, 3, 3, 2, 0, 1, 2, 3, 1, 3, 0, 0, 2, 2, 3, 0, 0,
# ...
